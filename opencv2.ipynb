# %% [markdown]
# <a href="https://colab.research.google.com/github/klisman02/Data-Analysis-Project/blob/main/opencv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow
from IPython.display import Image, display

# %%
face_classifier = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

if face_classifier.empty():
    print("Error loading cascade classifier. Please check the file path and name.")
else:
    print("Cascade classifier loaded successfully.")
# Out:
# Cascade classifier loaded successfully.

# %%
image = cv.imread('friends_cast.jpg')
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# %%
for (x, y, w, h) in faces:
  cv.rectangle(image,(x, y), (x + y, w + h), (255, 0, 0), 2)

# %%
cv2_imshow(image)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
